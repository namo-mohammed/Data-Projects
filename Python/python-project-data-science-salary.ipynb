# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/data-science-salary-2021-to-2023/Data Science Salary 2021 to 2023.csv

# %% [markdown]
# # Python
# ### Exploratory Data Analysis (EDA) - Data Visualisations
# #### Namo Mohammed

# %% [markdown]
# ### Dataset Overview
#
# ##### Source: Kaggle Dataset
# **Data Description**:
# This dataset aims to shed light on the salary trends in the field of Data Science for the years 2021 to 2023. <br> With a focus on various aspects of employment, including work experience, job titles, and company locations, this dataset provides valuable insights into salary distributions within the industry.
#
# Unveiling Data Science Salaries
#
# **Time Period**:
# 2021 to 2023 <br> <br>
# **Geography**:
# Worldwide Locations

# %%
# Importing Necessary Libraries
import pandas as pd #data manipulation and analysis
import matplotlib.pyplot as plt #data visualization
import seaborn as sns #high-level interface for drawing attractive and informative statistical graphics
import numpy as np #numerical computing
from tabulate import tabulate

# %% [markdown]
# ## Reading & Writing Data
# ### Reading from a CSV File

# %%
#Read CSV File and Convert it to Dataframe named Data
data=pd.read_csv("/kaggle/input/data-science-salary-2021-to-2023/Data Science Salary 2021 to 2023.csv")

# %% [markdown]
# ### Data Structure
# ##### Information about the .CSV Data File

# %%
data = pd.DataFrame(data)
data
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %%
#Display First 5 Rows
data.head()
# Out:
#    work_year experience_level employment_type                job_title  \
# 0       2023               EN              FT        Applied Scientist
# 1       2023               EN              FT        Applied Scientist
# 2       2023               EN              FT     Data Quality Analyst
# 3       2023               EN              FT  Compliance Data Analyst
# 4       2023               EN              FT        Applied Scientist
#
#    salary salary_currency  salary_in_usd company_location company_size
# 0  213660             USD         213660               US            L
# 1  130760             USD         130760               US            L
# 2  100000             USD         100000               NG            L
# 3   30000             USD          30000               NG            L
# 4  204620             USD         204620               US            L

# %%
#Display Last 5 Rows
data.tail()
# Out:
#       work_year experience_level employment_type                  job_title  \
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
#       salary salary_currency  salary_in_usd company_location company_size
# 3756  130000             EUR         148261               DE            M
# 3757   80000             EUR          91237               AT            S
# 3758  190200             USD         190200               US            M
# 3759   40000             EUR          45618               HR            S
# 3760  412000             USD         412000               US            L

# %%
#Concise Summary of Data
#Number of Entries (Rows), Number of Columns, Data Type, Number of Null Values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3761 entries, 0 to 3760
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   work_year         3761 non-null   int64
#  1   experience_level  3761 non-null   object
#  2   employment_type   3761 non-null   object
#  3   job_title         3761 non-null   object
#  4   salary            3761 non-null   int64
#  5   salary_currency   3761 non-null   object
#  6   salary_in_usd     3761 non-null   int64
#  7   company_location  3761 non-null   object
#  8   company_size      3761 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 264.6+ KB

# %%
#Descriptive Statistics 
data.describe()
# Out:
#          work_year        salary  salary_in_usd
# count  3761.000000  3.761000e+03    3761.000000
# mean   2022.374103  1.905999e+05  137555.178942
# std       0.691252  6.711457e+05   63022.267974
# min    2020.000000  6.000000e+03    5132.000000
# 25%    2022.000000  1.000000e+05   95000.000000
# 50%    2022.000000  1.375000e+05  135000.000000
# 75%    2023.000000  1.800000e+05  175000.000000
# max    2023.000000  3.040000e+07  450000.000000

# %%
#Data has 3761 Rows and 9 Columns
data.shape
# Out:
# (3761, 9)

# %%
#Top 20 Rows 
data[0:20]
# Out:
#     work_year experience_level employment_type                  job_title  \
# 0        2023               EN              FT          Applied Scientist
# 1        2023               EN              FT          Applied Scientist
# 2        2023               EN              FT       Data Quality Analyst
# 3        2023               EN              FT    Compliance Data Analyst
# 4        2023               EN              FT          Applied Scientist
# 5        2023               EN              FT          Applied Scientist
# 6        2023               EN              FT  Machine Learning Engineer
# 7        2023               EN              FT  Machine Learning Engineer
# 8        2023               EN              FT         Research Scientist
# 9        2023               EN              FT              Data Engineer
# 10       2023               EN              FT              Data Engineer
# 11       2023               EN              FT               Data Analyst
# ...

# %%
# Check for Duplicates
duplicates = data.duplicated()
print("Duplicate rows:\n", data[duplicates])
num_duplicates = duplicates.sum()
print("Number of duplicate rows:", num_duplicates)
# Out:
# Duplicate rows:
#        work_year experience_level employment_type       job_title   salary  \
# 14         2023               EN              FT    Data Analyst    75000
# 16         2023               EN              FT   Data Engineer    85000
# 17         2023               EN              FT   Data Engineer    65000
# 22         2023               EN              FT   Data Engineer    85000
# 23         2023               EN              FT   Data Engineer    65000
# ...         ...              ...             ...             ...      ...
# 3445       2022               SE              FT  Data Scientist   165000
# 3559       2021               MI              FT   Data Engineer   200000
# 3596       2021               MI              FT  Data Scientist    76760
# 3639       2021               SE              FT   Data Engineer   150000
# 3686       2020               EN              FT   Data Engineer  1000000
#
# ...

# %% [markdown]
# ### Key Features

# %%
#Looking for Null Values / Missing Values
data.isna().sum()
# Out:
# work_year           0
# experience_level    0
# employment_type     0
# job_title           0
# salary              0
# salary_currency     0
# salary_in_usd       0
# company_location    0
# company_size        0
# dtype: int64

# %%
#Data Types used in our Dataset
data.dtypes
# Out:
# work_year            int64
# experience_level    object
# employment_type     object
# job_title           object
# salary               int64
# salary_currency     object
# salary_in_usd        int64
# company_location    object
# company_size        object
# dtype: object

# %%
print(data)
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               EN              FT          Applied Scientist
# 1          2023               EN              FT          Applied Scientist
# 2          2023               EN              FT       Data Quality Analyst
# 3          2023               EN              FT    Compliance Data Analyst
# 4          2023               EN              FT          Applied Scientist
# ...         ...              ...             ...                        ...
# 3756       2020               SE              FT   Principal Data Scientist
# 3757       2020               SE              FT             Data Scientist
# 3758       2020               SE              FT       Data Science Manager
# 3759       2020               SE              FT  Machine Learning Engineer
# 3760       2020               SE              FT             Data Scientist
#
# ...

# %% [markdown]
# ## Finding Unqiue Values
# ##### We want to find Unique Values for each of our Columns

# %%
data.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'company_location',
#        'company_size'],
#       dtype='object')

# %% [markdown]
# Alright, we know that we have 9 columns in our dataset.
# Which are:
#
#     1. work_year - Representing the specific year of salary data collection
#     2. experience_level - The level of work experience of the employees, categorized as EN (Entry-Level), EX (Experienced), MI (Mid-Level), SE (Senior)
#     3. employment_type - The type of employment, labelled as FT (Full-Time), CT (Contractor), FL (Freelancer), PT (Part-Time)
#     4. job_title - The job titles of the employees, such as "Applied Scientist", "Data Quality Analyst", etc
#     5. salary - The salary figures in their respective currency formats
#     6. salary_currency - The currency code representing the salary
#     7. salary_in_usd - The converted salary figures in USD for uniform comparison
#     8. company_location - The location of the companies, specified as country codes (e.g., "US" for the United States and "NG" for Nigeria)
#     9. company_size - The size of the companies, classified as "L" (Large), "M" (Medium), and "S" (Small)

# %%
# 1. work year
work_year = data["work_year"].unique()
print("work_year", work_year)
# Out:
# work_year [2023 2022 2021 2020]

# %%
# 2. experience level
experience_level = data["experience_level"].unique()
print("experience_level", experience_level)
# Out:
# experience_level ['EN' 'EX' 'MI' 'SE']

# %%
# 3. employment type
employment_type = data["employment_type"].unique()
print("Date:", employment_type)
# Out:
# Date: ['FT' 'PT' 'CT' 'FL']

# %%
# 4. job title
job_title = data["job_title"].unique()
print("job_title", job_title)
# Out:
# job_title ['Applied Scientist' 'Data Quality Analyst' 'Compliance Data Analyst'
#  'Machine Learning Engineer' 'Research Scientist' 'Data Engineer'
#  'Data Analyst' 'Data Scientist' 'BI Data Engineer' 'Research Engineer'
#  'Business Data Analyst' 'Autonomous Vehicle Technician'
#  'Applied Machine Learning Scientist' 'AI Programmer' 'AI Developer'
#  'Computer Vision Engineer' 'BI Developer' 'Big Data Engineer'
#  'Deep Learning Engineer' 'Head of Data' 'Analytics Engineer'
#  'Data Architect' 'Director of Data Science' 'Head of Data Science'
#  'Data Analytics Manager' 'ML Engineer'
#  'Applied Machine Learning Engineer' 'Applied Data Scientist'
#  'ETL Engineer' 'Data Specialist' 'Lead Data Analyst' 'Data Manager'
#  'Machine Learning Scientist' 'MLOps Engineer' 'Financial Data Analyst'
#  'Software Data Engineer' 'Data Science Manager' 'Data Science Consultant'
#  'Machine Learning Infrastructure Engineer' 'Insight Analyst'
# ...

# %%
# 5. salary
salary = data["salary"].unique()
print("salary", salary)
# Out:
# salary [  213660   130760   100000    30000   204620   110680   163196   145885
#    220000    85000    65000    75000    70000  1400000    55000   130001
#     71907    60000   155000   125000    64200    56100    92700    61800
#     20000   160000   120000     7000    40000   190000   112000    62000
#     58000    90000    95000   115100    73900    80000   150000   200000
#     48000    78000   101400    50000   800000    12000   110000  1050000
#     25000   130000   135000   124234    74540  1060000   258750   185000
#    205000   329500   269600   145000   115000   175000   221000   153000
#    180000   286000   207000   353200   249300   265000   235000   194500
#    115500   210914   116704   167500   106500   310000   239000   131899
#    104891   210000   284000   236000   140000   314100   195800   300000
#    196200   150900    25500   162500   105380    64500   510000   105000
#   1700000    38000    35000    45000    47500   250000   230000   280700
# ...

# %%
# 6. salary currency
salary_currency = data["salary_currency"].unique()
print("salary_currency", salary_currency)
# Out:
# salary_currency ['USD' 'INR' 'CAD' 'EUR' 'CHF' 'PLN' 'BRL' 'GBP' 'HKD' 'SGD' 'THB' 'AUD'
#  'ILS' 'HUF' 'CZK' 'DKK' 'JPY' 'TRY' 'CLP' 'MXN']

# %%
# 7. salary in usd
salary_in_usd = data['salary_in_usd'].unique()
print("salary_in_usd", salary_in_usd)
# Out:
# salary_in_usd [213660 130760 100000 ... 190200  45618 412000]

# %%
# 8. company location
company_location = data['company_location'].unique()
print("company_location", company_location)

# Get unique company locations and their counts
company_location_counts = data['company_location'].value_counts()

# Print the unique company locations and their counts
print("Company Locations and Counts:\n", company_location_counts)
# Out:
# company_location ['US' 'NG' 'IN' 'CA' 'ES' 'GH' 'DE' 'CH' 'AU' 'SE' 'BR' 'GB' 'VN' 'BA'
#  'GR' 'HK' 'NL' 'FI' 'IE' 'SG' 'SI' 'MX' 'FR' 'HR' 'AM' 'KE' 'RO' 'TH'
#  'CF' 'UA' 'IL' 'CO' 'PT' 'EE' 'LV' 'MK' 'PK' 'IT' 'MA' 'AR' 'CR' 'IR'
#  'HU' 'AS' 'BE' 'AT' 'ID' 'LU' 'MY' 'CZ' 'DZ' 'RU' 'PL' 'LT' 'TR' 'BO'
#  'EG' 'AL' 'SK' 'PR' 'AE' 'DK' 'IQ' 'CN' 'BS' 'JP' 'CL' 'MD' 'MT' 'PH'
#  'HN' 'NZ']
# Company Locations and Counts:
#  company_location
# US    3045
# GB     173
# CA      87
# ES      77
# IN      58
#       ...
# CR       1
# MA       1
# AM       1
# MK       1
# NZ       1
# Name: count, Length: 72, dtype: int64

# %%
# 9. company size
company_size = data['company_size'].unique()
print("company_size", company_size)
# Out:
# company_size ['L' 'M' 'S']

# %% [markdown]
# ## Replacing Values

# %%
#Replacing Full Name of Short Forms of Experience Level, Employment Type and Company Size
data['experience_level'] = data['experience_level'].replace('EN', 'Entry-Level')
data['experience_level'] = data['experience_level'].replace('EX', 'Experienced')
data['experience_level'] = data['experience_level'].replace('MI', 'Mid-Level')
data['experience_level'] = data['experience_level'].replace('SE', 'Senior')

data['employment_type'] = data['employment_type'].replace('FT', 'Full-Time')
data['employment_type'] = data['employment_type'].replace('PT', 'Part-Time')
data['employment_type'] = data['employment_type'].replace('CT', 'Contractor')
data['employment_type'] = data['employment_type'].replace('FL', 'Freelancer')

data['company_size'] = data['company_size'].replace('L', 'Large')
data['company_size'] = data['company_size'].replace('M', 'Medium')
data['company_size'] = data['company_size'].replace('S', 'Small')

# %%
# Mapping Company Location to Location Names
company_location_dict = {
    'US': 'United States',
    'NG': 'Nigeria',
    'IN': 'India',
    'CA': 'Canada',
    'ES': 'Spain',
    'GH': 'Ghana',
    'DE': 'Germany',
    'CH': 'Switzerland',
    'AU': 'Australia',
    'SE': 'Sweden',
    'BR': 'Brazil',
    'GB': 'Great Britain',
    'VN': 'Vietnam',
    'BA': 'Bosnia and Herzegovina',
    'GR': 'Greece',
    'HK': 'Hong Kong',
    'NL': 'Netherlands',
    'FI': 'Finland',
    'IE': 'Ireland',
    'SG': 'Singapore',
    'SI': 'Slovenia',
    'MX': 'Mexico',
    'FR': 'France',
    'HR': 'Croatia',
    'AM': 'Armenia',
    'KE': 'Kenya',
    'RO': 'Romania',
    'TH': 'Thailand',
    'CF': 'Central African Republic',
    'UA': 'Ukraine',
    'IL': 'Israel',
    'CO': 'Colombia',
    'PT': 'Portugal',
    'EE': 'Estonia',
    'LV': 'Latvia',
    'MK': 'North Macedonia',
    'PK': 'Pakistan',
    'IT': 'Italy',
    'MA': 'Morocco',
    'AR': 'Argentina',
    'CR': 'Costa Rica',
    'IR': 'Iran',
    'HU': 'Hungary',
    'AS': 'American Samoa',
    'BE': 'Belgium',
    'AT': 'Austria',
    'ID': 'Indonesia',
    'LU': 'Luxembourg',
    'MY': 'Malaysia',
    'CZ': 'Czech Republic',
    'DZ': 'Algeria',
    'RU': 'Russia',
    'PL': 'Poland',
    'LT': 'Lithuania',
    'TR': 'Turkey',
    'BO': 'Bolivia',
    'EG': 'Egypt',
    'AL': 'Albania',
    'SK': 'Slovakia',
    'PR': 'Puerto Rico',
    'AE': 'United Arab Emirates',
    'DK': 'Denmark',
    'IQ': 'Iraq',
    'CN': 'China',
    'BS': 'Bahamas',
    'JP': 'Japan',
    'CL': 'Chile',
    'MD': 'Moldova',
    'MT': 'Malta',
    'PH': 'Philippines',
    'HN': 'Honduras',
    'NZ': 'New Zealand'
}

data['company_location'] = data['company_location'].map(company_location_dict)

# %% [markdown]
# ## Renaming Columns

# %%
# List of New Column Names
data.columns = ['Work Year', 'Experience Level', 'Employment Type', 'Job Title', 'Salary', 'Salary Currency', 
                'Salary in USD', 'Company Location', 'Company Size']

# %% [markdown]
# ## Saving File to a new .CSV

# %%
# Save the DataFrame to a CSV file
data.to_csv('new_file.csv', index=False)

print("DataFrame has been saved to new_file.csv")
# Out:
# DataFrame has been saved to new_file.csv

# %% [markdown]
# ## Grouping Data

# %%
#Top 20 Salaries in USD
top_20_salaries = data.nlargest(20, 'Salary in USD')
print(top_20_salaries[['Salary in USD','Job Title']])
# Out:
#       Salary in USD                           Job Title
# 3714         450000                  Research Scientist
# 2008         430967                        Data Analyst
# 893          423834                        AI Scientist
# 3609         423000  Applied Machine Learning Scientist
# 3519         416000            Principal Data Scientist
# 3760         412000                      Data Scientist
# 3449         405000                 Data Analytics Lead
# 1414         385000                        Data Analyst
# 3450         380000              Applied Data Scientist
# 966          376080                      Data Architect
# 2320         375000  Machine Learning Software Engineer
# 2685         375000              Data Science Tech Lead
# 1284         370000                      Data Scientist
# 1432         370000                  Research Scientist
# 136          353200            Director of Data Science
# 1501         350000                   Applied Scientist
# ...

# %%
# Average Salary in USD by Employment Type and Work Year
grouped_data = data.groupby(['Work Year', 'Employment Type'])['Salary in USD'].mean().round(2)

# Print
print(grouped_data)
# Out:
# Work Year  Employment Type
# 2020       Contractor         100000.00
#            Freelancer          60000.00
#            Full-Time           94685.62
#            Part-Time           18817.50
# 2021       Contractor         263666.67
#            Freelancer          25851.67
#            Full-Time           94996.85
#            Part-Time           22455.14
# 2022       Contractor          46992.25
#            Freelancer          70130.75
#            Full-Time          134029.25
#            Part-Time           65639.00
# 2023       Contractor          27750.00
#            Freelancer          50000.00
#            Full-Time          149274.90
#            Part-Time           17779.00
# Name: Salary in USD, dtype: float64

# %%
# Average Salary in USD by Employment Type and Work Year
grouped_data1 = data.groupby(['Work Year', 'Employment Type'])['Salary in USD'].max().round(2)

# Print
print(grouped_data1)
# Out:
# Work Year  Employment Type
# 2020       Contractor         100000
#            Freelancer          60000
#            Full-Time          450000
#            Part-Time           21669
# 2021       Contractor         416000
#            Freelancer          45555
#            Full-Time          423000
#            Part-Time           69741
# 2022       Contractor          90000
#            Freelancer         100000
#            Full-Time          430967
#            Part-Time          125404
# 2023       Contractor          30000
#            Freelancer          50000
#            Full-Time          423834
#            Part-Time           17779
# Name: Salary in USD, dtype: int64

# %%
# Average Salary in USD by Work Year
grouped_data1 = data.groupby(['Work Year', 'Company Location'])['Salary in USD'].mean().round(2)
print(grouped_data1)
# Out:
# Work Year  Company Location
# 2020       Austria              82683.50
#            Canada               66052.00
#            Croatia              45618.00
#            Denmark              45896.00
#            France               50066.40
#                                  ...
# 2023       Switzerland         121093.00
#            Thailand             27096.50
#            Ukraine              72666.67
#            United States       156715.14
#            Vietnam              12000.00
# Name: Salary in USD, Length: 146, dtype: float64

# %% [markdown]
# ## Pivot Table

# %%
# Create a Pivot Table
pivot_table = pd.pivot_table(data,
                             values='Salary in USD',
                             index=['Job Title'],
                             aggfunc='mean')
pivot_table
# Out:
#                                Salary in USD
# Job Title
# 3D Computer Vision Researcher   21352.250000
# AI Developer                   136666.090909
# AI Programmer                   55000.000000
# AI Scientist                   110120.875000
# Analytics Engineer             152368.631068
# ...                                      ...
# Research Engineer              163108.378378
# Research Scientist             161214.195122
# Software Data Engineer          62510.000000
# Staff Data Analyst              15000.000000
# Staff Data Scientist           105000.000000
#
# [93 rows x 1 columns]

# %%
# Create a Pivot Table
pivot_table = pd.pivot_table(data,
                             values='Salary in USD',
                             index=['Job Title'],
                             aggfunc='mean')
pivot_table
# Out:
#                                Salary in USD
# Job Title
# 3D Computer Vision Researcher   21352.250000
# AI Developer                   136666.090909
# AI Programmer                   55000.000000
# AI Scientist                   110120.875000
# Analytics Engineer             152368.631068
# ...                                      ...
# Research Engineer              163108.378378
# Research Scientist             161214.195122
# Software Data Engineer          62510.000000
# Staff Data Analyst              15000.000000
# Staff Data Scientist           105000.000000
#
# [93 rows x 1 columns]

# %%
# Sort the Pivot Table by 'Salary in USD' in Descending Order and get the Top 20
top_20 = pivot_table.sort_values(by='Salary in USD', ascending=False).head(20)

# Display the Top 20 Job Titles by Average Salary
print(top_20)
# Out:
#                                      Salary in USD
# Job Title
# Data Science Tech Lead               375000.000000
# Cloud Data Architect                 250000.000000
# Data Lead                            212500.000000
# Data Analytics Lead                  211254.500000
# Principal Data Scientist             198171.125000
# Director of Data Science             195140.727273
# Principal Data Engineer              192500.000000
# Machine Learning Software Engineer   192420.000000
# Data Science Manager                 191278.775862
# Applied Scientist                    190264.482759
# Principal Machine Learning Engineer  190000.000000
# Head of Data                         183857.500000
# Data Infrastructure Engineer         175051.666667
# Business Intelligence Engineer       174150.000000
# Machine Learning Scientist           163220.076923
# Research Engineer                    163108.378378
# Data Architect                       161713.772277
# ...

# %% [markdown]
# ## Charts

# %%
# Create a Figure with 2 Subplots (1 Row, 2 Columns)
fig, ax = plt.subplots(1, 2, figsize=(15, 6))

# First Subplot: Bar Chart for Work Year
counts_work_year = data["Work Year"].value_counts().sort_index()
bars1 = ax[0].bar(counts_work_year.index, counts_work_year.values, color=["#FF5733", "#33FF57", "#3357FF", "#F3FF33"], edgecolor="black", linewidth=1.2)
ax[0].set_title("Job Count for Each Work Year", fontsize=12, fontweight="bold")
ax[0].set_xlabel("Work Year", fontsize=12)
ax[0].set_ylabel("Amount of Jobs", fontsize=12)
ax[0].set_xticks(counts_work_year.index)
ax[0].set_xticklabels(counts_work_year.index, rotation=45)

# Adding Counts on Top of the Bars for the First Subplot
ax[0].bar_label(bars1, label_type='edge', fontsize=10, fontweight='bold')

# Second Subplot: Bar chart for Company Size
counts_company_size = data["Company Size"].value_counts().sort_index()
bars2 = ax[1].bar(counts_company_size.index, counts_company_size.values, color=["#FF5733", "#33FF57", "#3357FF", "#F3FF33"], edgecolor="black", linewidth=1.2)
ax[1].set_title("Job Count for Company Sizes", fontsize=12, fontweight="bold")
ax[1].set_xlabel("Company Size", fontsize=12)
ax[1].set_ylabel("Amount of Jobs", fontsize=12)
ax[1].set_xticks(range(len(counts_company_size)))
ax[1].set_xticklabels(counts_company_size.index, rotation=45)

# Adding Counts on Top of the Bars for the Second Subplot
ax[1].bar_label(bars2, label_type='edge', fontsize=10, fontweight='bold')

# Adjust Layout to Prevent Overlap
plt.tight_layout()

# Show the Plots
plt.show()

# %% [markdown]
# **Insights**
#
# We find data for the year 2020 even though the description of the dataset aims to shed light on the salary trends in the field of Data Science for the years 2021 to 2023.
#
# The year 2023 had the highest amount of Data Science jobs. In total there were 1789 jobs available worldwide. We can see an increase in jobs available each year. 2020 we only have 76 jobs and then we leap forward to 2022 & 2023 with a significant difference with figures in the thousands.
#
# In addition to this, Medium Size companies had the greatest number of jobs available with a total of 3157 jobs across the board.

# %%
# Get the Top 20 Salaries
top_20_salaries = data.nlargest(20, 'Salary in USD')

# Create a Unique Identifier for Plotting Purposes
top_20_salaries['Unique Job Title'] = top_20_salaries['Job Title'] + ' (' + top_20_salaries['Company Location'] + ') '
top_20_salaries['Unique Job Title'] += top_20_salaries.index.astype(str)

# Get the Bottom 20 Salaries
bottom_20_salaries = data.nsmallest(20, 'Salary in USD')

# Create a Unique Identifier for Plotting Purposes, including Employment Type
bottom_20_salaries['Unique Job Title'] = (bottom_20_salaries['Job Title'] + ' (' +
                                          bottom_20_salaries['Company Location'] + ', ' +
                                          bottom_20_salaries['Employment Type'] + ') ' +
                                          bottom_20_salaries.index.astype(str))

# Create Subplots
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12,14))

# Plotting the Top 20 Salaries Bar Chart with Customizations
bars_top = axes[0].barh(top_20_salaries['Unique Job Title'], top_20_salaries['Salary in USD'], color='mediumseagreen')

# Remove the Lines at the end of the Bars by setting Edgecolor to 'none' and Linewidth to 0
for bar in bars_top:
    bar.set_edgecolor('none')
    bar.set_linewidth(0)

# Add Borders to the Columns
for bar in bars_top:
    bar.set_edgecolor('black')
    bar.set_linewidth(1)
    
# Use the Original Job Titles with Company Location for the y-axis Labels
axes[0].set_yticks(range(len(top_20_salaries)))
axes[0].set_yticklabels(top_20_salaries['Job Title'] + ' (' + top_20_salaries['Company Location'] + ')')

axes[0].set_xlabel('Salary in $ USD', fontsize=12)
axes[0].set_ylabel('Job Title (Company Location)', fontsize=12)
axes[0].set_title('Top 20 Data Science Salaries by Job Title and Location', fontsize=14, fontweight='bold')
axes[0].invert_yaxis() # Invert y-axis to have the Highest Salary on Top

# Plotting the Bottom 20 Salaries Bar Chart with Customizations
bars_bottom = axes[1].barh(bottom_20_salaries['Unique Job Title'], bottom_20_salaries['Salary in USD'], color='darkorange')

# Remove the Lines at the end of the Bars by setting Edgecolor to 'none' and Linewidth to 0
for bar in bars_bottom:
    bar.set_edgecolor('none')
    bar.set_linewidth(0)

# Add Borders to the Columns
for bar in bars_bottom:
    bar.set_edgecolor('black')
    bar.set_linewidth(1)
    
# Use the Original Job Titles with Company Location and Employment Type for the y-axis Labels
axes[1].set_yticks(range(len(bottom_20_salaries)))
axes[1].set_yticklabels(bottom_20_salaries['Job Title'] + ' (' +
                        bottom_20_salaries['Company Location'] + ', ' +
                        bottom_20_salaries['Employment Type'] + ')')

axes[1].set_xlabel('Salary in $ USD', fontsize=12)
axes[1].set_ylabel('Job Title (Company Location, Employment Type)', fontsize=12)
axes[1].set_title('Bottom 20 Data Science Salaries by Job Title, Location and Employment Type', fontsize=14, fontweight='bold')
axes[1].invert_yaxis() # Invert y-axis to have the highest salary on top

# Adjust Layout and Show the Plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insights**
#
# The United States dominates the list of the highest-paying Data Science roles, with 18 out of the top 20 positions based there, while the remaining two are in Great Britain and Israel. Salaries for these roles range from 300,000 to over 400,000 USD.
#
# On the lower end, the least-paying Data Science jobs are primarily found in Asia, Africa, and South America, offering salaries between 4,000 and 8,000 USD.

# %%
# Calculate the Counts of Each Experience Level
work_year_counts = data['Experience Level'].value_counts()

# Ensure the Explode Parameter Matches the Number of Slices
explode = (0.1, 0, 0) if len(work_year_counts) == 3 else (0.1, 0, 0, 0)

# Define a Color Palette
palette = sns.color_palette("pastel", len(work_year_counts))

# Function to Display Both Percentage and Count
def autopct_format(values):
    def my_format(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return f'{pct:.1f}%\n({val:d})'
    return my_format

# Plotting the Pie Chart with Additional Customizations
plt.figure(figsize=(7,7))
plt.pie(work_year_counts, 
        labels=work_year_counts.index, 
        autopct=autopct_format(work_year_counts), 
        colors=palette, 
        explode=explode, 
        shadow=True,
        textprops={'fontweight': 'light'})  # Make labels bold

plt.title('Experience Level Distribution For All Data Science Jobs', fontsize=14, fontweight='bold')

# Add a Legend
plt.legend(title="Experience Level", loc="upper right")

# Display the Plot
plt.show()

# %%
# Create a Line Chart for Each Employment Type
plt.figure(figsize=(11 ,8)) # Set the figure size

for employment_type in grouped_data.index.get_level_values('Employment Type').unique():
    plt.plot(grouped_data.loc[(slice(None), employment_type)].index.get_level_values('Work Year'), 
             grouped_data.loc[(slice(None), employment_type)].values, 
             marker='o' , linestyle='-', linewidth=2.5,
             label=employment_type)

plt.title('Average Salary in USD by Employment Type and Work Year' , fontsize=16 , fontweight='bold')
plt.xlabel('Work Year' , fontsize=14)
plt.ylabel('Average Salary in $ USD' , fontsize=14)
plt.xticks(rotation=45 , fontsize=12)
plt.yticks(fontsize=12)
plt.legend(title='Employment Type' , fontsize=12)
plt.grid(True , linestyle='' , alpha=0.7)
plt.tight_layout() # Adjust Layout to Prevent Clipping of Labels

# Change the Background Color of the Chart
ax = plt.gca()
ax.set_facecolor('#f7f8f1') # Light Grey Background Color

# Remove Decimals from Dates on the x-axis
ax = plt.gca()
ax.xaxis.get_major_formatter().set_useOffset(False)
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x,_: f'{int(x)}'))

plt.show()

# %% [markdown]
# # Summary Insights
#
# From the Data Science Salary sample Dataset we have analysed, we now have a better overall understanding on the Data Science job market across different locations around the world. We see an increase in available jobs year on year and the locations in which these jobs are. There is noticeably a huge difference in the salaries in USD, but we must bear in mind the cost of living and other economic factors in these locations.
#
# **Key Findings**
#
# * Salary ranges vary, with a substantial difference between the highest and lowest salaries globally
# * There has been a year-on-year increase in Data Science jobs, reflecting growing demand in the field
# * The majority of job postings are from medium-sized companies, followed by large companies, with the fewest postings coming from small companies

# %%
# Top 20 Rows - Final Look of Sample Dataset
data[0:20]
# Out:
#     Work Year Experience Level Employment Type                  Job Title  \
# 0        2023      Entry-Level       Full-Time          Applied Scientist
# 1        2023      Entry-Level       Full-Time          Applied Scientist
# 2        2023      Entry-Level       Full-Time       Data Quality Analyst
# 3        2023      Entry-Level       Full-Time    Compliance Data Analyst
# 4        2023      Entry-Level       Full-Time          Applied Scientist
# 5        2023      Entry-Level       Full-Time          Applied Scientist
# 6        2023      Entry-Level       Full-Time  Machine Learning Engineer
# 7        2023      Entry-Level       Full-Time  Machine Learning Engineer
# 8        2023      Entry-Level       Full-Time         Research Scientist
# 9        2023      Entry-Level       Full-Time              Data Engineer
# 10       2023      Entry-Level       Full-Time              Data Engineer
# 11       2023      Entry-Level       Full-Time               Data Analyst
# ...
